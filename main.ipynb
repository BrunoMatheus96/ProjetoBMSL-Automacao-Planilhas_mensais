# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import rodar_automacao_mensal

rodar_automacao_mensal()
# Out:
# 🚀 Iniciando automação...
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=352114749237-fjua48p9ba1qi612gifv9c5t7amppdp0.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A50689%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=8G9vBiMmBnWL93qcDxqveZ7vCnivWR&code_challenge=_BN5ZbehSry0rcz8ks6AmvVy0wjMI-Jupgrec5Qpfg4&code_challenge_method=S256&access_type=offline
# Download concluído ✅
#              Nome  Valor      Dia        Hora  \
# 0  Manoela Dualib  350.0  Segunda  15h às 16h
# 1             NaN    NaN   Quarta  16h às 17h
#
#                                             Endereco
# 0  R. Cravinhos, 114 - apto 51 - Jardim Paulista,...
# 1                                                NaN
# ID da pasta 2026: 1PmPhGniQo2s_67YokCUESG3B7jRnVr84
# Mês anterior: Março
# Mês atual: Abril
# Duplicado com sucesso
# ...
