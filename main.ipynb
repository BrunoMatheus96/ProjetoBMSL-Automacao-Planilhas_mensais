# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import rodar_automacao_mensal

rodar_automacao_mensal()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.workflows.planilha_mensal_workflow import rodar_automacao_mensal
#       2
#       3 rodar_automacao_mensal()
#
# File c:\Users\bruno\OneDrive\Documentos\Projetos\ProjetoBMSL-Automacao-Planilhas_Mensais\src\workflows\planilha_mensal_workflow.py:1
# ----> 1 from src.tarefas import listar_arquivos
#       2 from src.tarefas.baixar_arquivo import baixar_alunos
#       3 from src.tarefas.duplicar_planilha import duplicar_mes
#
# File c:\Users\bruno\OneDrive\Documentos\Projetos\ProjetoBMSL-Automacao-Planilhas_Mensais\src\tarefas\listar_arquivos.py:1
# ----> 1 from servicos.google_drive_servico import GoogleDriveServico
#       2 from datetime import datetime
#       3 import locale
#
# ModuleNotFoundError: No module named 'servicos'
